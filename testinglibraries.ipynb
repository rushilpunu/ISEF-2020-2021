# %% [markdown]
# <a href="https://colab.research.google.com/github/rushilpunu/ISEF-2020-2021/blob/dev/testinglibraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kirkthaker/investopedia-trading-api.git
# !pip3 install investopediaApi
# Out:
# Cloning into 'investopedia-trading-api'...
# remote: Enumerating objects: 331, done.
# remote: Total 331 (delta 0), reused 0 (delta 0), pack-reused 331
# Receiving objects: 100% (331/331), 82.79 KiB | 1.72 MiB/s, done.
# Resolving deltas: 100% (139/139), done.
# ...
#   Created wheel for investopediaApi: filename=InvestopediaApi-1.1-cp36-none-any.whl size=4184 sha256=0d31cdee3666b22c412f9ea67d6b600a5dd2399779332fe629a7e7c20fedaf5b
#   Stored in directory: /root/.cache/pip/wheels/fa/18/3d/186a8eef939d396aed68ded9672d3b6c440582830b10b20a5f
# Successfully built investopediaApi
# ...

# %%
from InvestopediaApi import ita
import tensorflow
import sklearn
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# !pip3 install alpha_vantage
# Out:
# ...
#      |████████████████████████████████| 1.3MB 5.1MB/s
# ...
#      |████████████████████████████████| 296kB 21.5MB/s
# ...
#      |████████████████████████████████| 143kB 18.6MB/s
# ...
#   Created wheel for alpha-vantage: filename=alpha_vantage-2.2.0-cp36-none-any.whl size=25706 sha256=703ddaeb83d1947c9cc16c6b2f2ea596fcc31c64fb6904a87bfaf73fe31b7c0f
#   Stored in directory: /root/.cache/pip/wheels/3a/fa/05/80b0afcbd2a4de8bd2a0c5cd77084e3d3a9cc12c48be9b7f84
# ...
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3161 sha256=15a4fe85a335d443980c983405a8be68945d639f020d18a80e554d72e10224af
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
# Successfully built alpha-vantage idna-ssl
# ...

# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries
#Key below
key = '9XUZ1EJ93CBPKBEZ'

ts = TimeSeries(key)
aapl, meta = ts.get_daily(symbol='AAPL')
print(aapl['2020-11-04'])
# Out:
# {'1. open': '114.1400', '2. high': '115.5900', '3. low': '112.3500', '4. close': '114.9500', '5. volume': '138235482'}

# %%
from alpha_vantage.techindicators import TechIndicators
import matplotlib
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# %%
#Key below
key = '9XUZ1EJ93CBPKBEZ'
#Choose output type
ts = TimeSeries(key, output_format='pandas')
ti = TechIndicators(key)

# %%
#aapl data is pandas dataframe, but aapl meta_data is a dict
aapl_data, aaple_meta_data = ts.get_daily(symbol='AAPL')
#aapl_sma is a dict, aapl_meta_sma is also dict
aapl_sma, aapl_meta_sma = ti.get_sma(symbol='AAPL')

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
import math
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
plt.style.use('fivethirtyeight')

# %%
df = web.DataReader('AAPL', data_source='yahoo' , start='2020-03-01', end='2020-05-11')
df
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-03-02  75.360001  69.430000  70.570000  74.702499  341397200.0  74.366737
# 2020-03-03  76.000000  71.449997  75.917503  72.330002  319475600.0  72.004913
# 2020-03-04  75.849998  73.282501  74.110001  75.684998  219178400.0  75.344826
# 2020-03-05  74.887497  72.852501  73.879997  73.230003  187572800.0  72.900864
# 2020-03-06  72.705002  70.307503  70.500000  72.257500  226176800.0  71.932739
# 2020-03-09  69.522499  65.750000  65.937500  66.542503  286744800.0  66.243423
# 2020-03-10  71.610001  67.342499  69.285004  71.334999  285290000.0  71.014381
# 2020-03-11  70.305000  67.964996  69.347504  68.857498  255598800.0  68.548012
# 2020-03-12  67.500000  62.000000  63.985001  62.057499  418474000.0  61.778580
# 2020-03-13  69.980003  63.237499  66.222504  69.492500  370732000.0  69.180161
# 2020-03-16  64.769997  60.000000  60.487499  60.552502  322423600.0  60.280346
# ...

# %%
#visualization
plt.figure(figsize=(20,8))
plt.title('Closing Price History')
plt.xlabel('Date', fontsize=20)
plt.plot(df['Close'])
plt.ylabel('Close Price', fontsize=18)
plt.show()

# %%
#Create new dataframe; only close column
data = df.filter(['Close'])
#convert data to numpy array
dataset = data.values
#get the number of rows
training_data_len = math.ceil(len(dataset) * 0.8)

print(training_data_len)
# Out:
# 40
